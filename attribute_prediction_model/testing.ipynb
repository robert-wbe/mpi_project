# %%
import torch
import torchvision
from model import model

# %%
model(torch.rand(5, 3, 128, 128))
# Out:
# tensor([[0.5595, 0.4334, 0.4863, 0.4956, 0.5786, 0.5456, 0.3915, 0.6222, 0.5219,
#          0.6404, 0.5856, 0.5110, 0.5030, 0.5025, 0.3791, 0.4135, 0.6132, 0.4658,
#          0.5417, 0.4063, 0.5520, 0.4863, 0.4486, 0.5802, 0.4430, 0.5454, 0.4850,
#          0.4511, 0.3675, 0.5447, 0.4610, 0.5748, 0.6018, 0.4398, 0.3886, 0.5245,
#          0.4732, 0.4772, 0.5517, 0.4157],
#         [0.5460, 0.4112, 0.4710, 0.5149, 0.5827, 0.5149, 0.3945, 0.5939, 0.5445,
#          0.6588, 0.5674, 0.5272, 0.4883, 0.4415, 0.4135, 0.4012, 0.5897, 0.4308,
#          0.5434, 0.4125, 0.5234, 0.4933, 0.4333, 0.6217, 0.4231, 0.5878, 0.5137,
#          0.4582, 0.3794, 0.5574, 0.4951, 0.5400, 0.5959, 0.4398, 0.3707, 0.5402,
#          0.5013, 0.4381, 0.5183, 0.4071],
#         [0.5360, 0.4194, 0.5098, 0.5262, 0.5762, 0.4725, 0.3531, 0.6242, 0.5752,
#          0.6617, 0.5701, 0.5172, 0.4805, 0.5187, 0.3748, 0.4913, 0.6143, 0.4694,
# ...
